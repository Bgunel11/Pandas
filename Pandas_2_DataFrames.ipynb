# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # DataFrames Basics

# %%
my_data = np.random.randint(0, 101, size=(5,4))
my_data
# Out:
# array([[76, 41, 21,  3],
#        [93, 27, 31,  5],
#        [48,  2, 51, 58],
#        [16, 58, 51, 62],
#        [13, 94, 51, 34]])

# %%
pd.DataFrame(my_data)
# Out:
#     0   1   2   3
# 0  76  41  21   3
# 1  93  27  31   5
# 2  48   2  51  58
# 3  16  58  51  62
# 4  13  94  51  34

# %%
my_idx =['TR', 'BR', 'USA', 'RU']
my_cols = ['Jan', 'Feb', 'Mar']
my_data = np.random.randint(0, 101, size=(4, 3))

# %%
my_data
# Out:
# array([[55, 14, 68],
#        [42, 57, 19],
#        [92, 78,  7],
#        [65,  7, 22]])

# %%
df = pd.DataFrame(data= my_data, index= my_idx, columns= my_cols)
df
# Out:
#      Jan  Feb  Mar
# TR    55   14   68
# BR    42   57   19
# USA   92   78    7
# RU    65    7   22

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, TR to RU
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Jan     4 non-null      int64
#  1   Feb     4 non-null      int64
#  2   Mar     4 non-null      int64
# dtypes: int64(3)
# memory usage: 300.0+ bytes

# %%
df.index = ['Zehra', 'Ayse', 'Mehmet', 'Tunc']

# %%
df.columns = ['1-Not', '2-Not', '3- Not']

# %%
df
# Out:
#         1-Not  2-Not  3- Not
# Zehra      55     14      68
# Ayse       42     57      19
# Mehmet     92     78       7
# Tunc       65      7      22

# %% [markdown]
# # Hazır data çağırmaq

# %%
# !pwd
# Out:
# /content

# %%
# !wget https://raw.githubusercontent.com/EmKa-Academy/Canli-Ders-Notebooklari/refs/heads/main/Batch-1/Pandas-Dersleri/DATA/tips.csv
# Out:
# --2025-03-06 10:39:28--  https://raw.githubusercontent.com/EmKa-Academy/Canli-Ders-Notebooklari/refs/heads/main/Batch-1/Pandas-Dersleri/DATA/tips.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18505 (18K) [text/plain]
# Saving to: ‘tips.csv.2’
#
# tips.csv.2          100%[===================>]  18.07K  --.-KB/s    in 0.001s
#
# 2025-03-06 10:39:28 (28.4 MB/s) - ‘tips.csv.2’ saved [18505/18505]

# %%
df = pd.read_csv('/content/tips.csv')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.head(7) #başdan 7 sətir
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
# 5       25.29  4.71    Male     No  Sun  Dinner     4              6.32
# 6        8.77  2.00    Male     No  Sun  Dinner     2              4.38
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251
# 5          Erik Smith   213140353657882    Sun9679
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df.tail(7) #sondan 7 sətir
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 237       32.83  1.17    Male    Yes   Sat  Dinner     2             16.42
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 237     Thomas Brown  4284722681265508    Sat2929
# 238   Kimberly Crane      676184013727    Sat9777
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# ...

# %%
df.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# 239    Michael Avila  5296068606052842    Sat2657
# 240   Monica Sanders  3506806155565404    Sat1766
# 241       Keith Wong  6011891618747196    Sat3880
# 242     Dennis Dixon     4375220550950      Sat17
# 243  Michelle Hardin  3511451626698139    Thur672

# %%
df.sample()
# Out:
#     total_bill   tip     sex smoker   day   time  size  price_per_person  \
# 82       10.07  1.83  Female     No  Thur  Lunch     1             10.07
#
#      Payer Name     CC Number Payment ID
# 82  Julie Moody  630413282843   Thur4909

# %%
df.sample(6)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 25        17.81  2.34    Male     No   Sat  Dinner     4              4.45
# 72        26.86  3.14  Female    Yes   Sat  Dinner     2             13.43
# 119       24.08  2.92  Female     No  Thur   Lunch     4              6.02
# 33        20.69  2.45  Female     No   Sat  Dinner     4              5.17
# 41        17.46  2.54    Male     No   Sun  Dinner     2              8.73
# 5         25.29  4.71    Male     No   Sun  Dinner     4              6.32
#
#              Payer Name         CC Number Payment ID
# 25       Robert Perkins    30502930499388     Sat907
# 72   Victoria Obrien MD     4216245673726    Sat1967
# 119      Melanie Jordan      676212062720   Thur8063
# 33        Amber Francis   377742985258914    Sat6649
# 41          David Boyer  3536678244278149    Sun9460
# 5            Erik Smith   213140353657882    Sun9679

# %%
df.shape
# Out:
# (244, 11)

# %%
df.shape[0] #sətir sayı
# Out:
# 244

# %%
df.shape[1] #sütun sayı
# Out:
# 11

# %%
df.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size',
#        'price_per_person', 'Payer Name', 'CC Number', 'Payment ID'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   total_bill        244 non-null    float64
#  1   tip               244 non-null    float64
#  2   sex               244 non-null    object
#  3   smoker            244 non-null    object
#  4   day               244 non-null    object
#  5   time              244 non-null    object
#  6   size              244 non-null    int64
#  7   price_per_person  244 non-null    float64
#  8   Payer Name        244 non-null    object
#  9   CC Number         244 non-null    int64
#  10  Payment ID        244 non-null    object
# dtypes: float64(3), int64(2), object(6)
# memory usage: 21.1+ KB

# %%
df.describe()
# Out:
#        total_bill         tip        size  price_per_person     CC Number
# count  244.000000  244.000000  244.000000        244.000000  2.440000e+02
# mean    19.785943    2.998279    2.569672          7.888197  2.563496e+15
# std      8.902412    1.383638    0.951100          2.914234  2.369340e+15
# min      3.070000    1.000000    1.000000          2.880000  6.040679e+10
# 25%     13.347500    2.000000    2.000000          5.800000  3.040731e+13
# 50%     17.795000    2.900000    2.000000          7.255000  3.525318e+15
# 75%     24.127500    3.562500    3.000000          9.390000  4.553675e+15
# max     50.810000   10.000000    6.000000         20.270000  6.596454e+15

# %%
df.describe().T
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %% [markdown]
# # Columnlar üzərində yerinə yetirilən işlər

# %%
df['price_per_person'] #Series olaraq sütunu çağırmış olduq
# Out:
# 0       8.49
# 1       3.45
# 2       7.00
# 3      11.84
# 4       6.15
#        ...
# 239     9.68
# 240    13.59
# 241    11.34
# 242     8.91
# 243     9.39
# Name: price_per_person, Length: 244, dtype: float64

# %%
df[['price_per_person']] # 1 sütunlu DataFrame kimi çəkmiş olduq
# Out:
#      price_per_person
# 0                8.49
# 1                3.45
# 2                7.00
# 3               11.84
# 4                6.15
# ..                ...
# 239              9.68
# 240             13.59
# 241             11.34
# 242              8.91
# 243              9.39
#
# [244 rows x 1 columns]

# %%
df[['sex', 'tip']]
# Out:
#         sex   tip
# 0    Female  1.01
# 1      Male  1.66
# 2      Male  3.50
# 3      Male  3.31
# 4    Female  3.61
# ..      ...   ...
# 239    Male  5.92
# 240  Female  2.00
# 241    Male  2.00
# 242    Male  1.75
# 243  Female  3.00
#
# [244 rows x 2 columns]

# %%
#Insanların bonkörlük səviyyəsini hesablayaq
# Verdikləri əlavə çay pulu / ümumi hesab  * 100

# %%
df['tip'] / df['total_bill'] * 100
# Out:
# 0       5.944673
# 1      16.054159
# 2      16.658734
# 3      13.978041
# 4      14.680765
#          ...
# 239    20.392697
# 240     7.358352
# 241     8.822232
# 242     9.820426
# 243    15.974441
# Length: 244, dtype: float64

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df['Bonkörlük_faizi'] = df['tip'] / df['total_bill'] * 100

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  Bonkörlük_faizi
# 0  Christy Cunningham  3560325168603410    Sun2959         5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608        16.054159
# 2      Travis Walters  6011812112971322    Sun4458        16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260        13.978041
# 4        Tonya Carter  4832732618637221    Sun2251        14.680765

# %%
df.drop('Payment ID', axis = 1)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number  Bonkörlük_faizi
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID  Bonkörlük_faizi
# 0  Christy Cunningham  3560325168603410    Sun2959         5.944673
# 1      Douglas Tucker  4478071379779230    Sun4608        16.054159
# 2      Travis Walters  6011812112971322    Sun4458        16.658734
# 3    Nathaniel Harris  4676137647685994    Sun5260        13.978041
# 4        Tonya Carter  4832732618637221    Sun2251        14.680765

# %%
df.drop('Payment ID', axis = 1, inplace= True)

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number  Bonkörlük_faizi
# 0  Christy Cunningham  3560325168603410         5.944673
# 1      Douglas Tucker  4478071379779230        16.054159
# 2      Travis Walters  6011812112971322        16.658734
# 3    Nathaniel Harris  4676137647685994        13.978041
# 4        Tonya Carter  4832732618637221        14.680765

# %%
df.drop(['Bonkörlük_faizi', 'Payer Name'], axis= 1,inplace=False)
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#             CC Number
# 0    3560325168603410
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number  Bonkörlük_faizi
# 0  Christy Cunningham  3560325168603410         5.944673
# 1      Douglas Tucker  4478071379779230        16.054159
# 2      Travis Walters  6011812112971322        16.658734
# 3    Nathaniel Harris  4676137647685994        13.978041
# 4        Tonya Carter  4832732618637221        14.680765

# %% [markdown]
# # Row(sətir) işləri

# %%
df['tip'] #Series tipində sütun çağırmaq
# Out:
# 0      1.01
# 1      1.66
# 2      3.50
# 3      3.31
# 4      3.61
#        ...
# 239    5.92
# 240    2.00
# 241    2.00
# 242    1.75
# 243    3.00
# Name: tip, Length: 244, dtype: float64

# %%
df[['tip']] #Dataframe tipində sütun çağırmaq
# Out:
#       tip
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# ..    ...
# 239  5.92
# 240  2.00
# 241  2.00
# 242  1.75
# 243  3.00
#
# [244 rows x 1 columns]

# %%
#Sətir çağırmaq üçün .loc və .iloc metodlarından istifadə olunur.

# %%
df.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
df.head(3)
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
#
#            Payer Name         CC Number  Bonkörlük_faizi
# 0  Christy Cunningham  3560325168603410         5.944673
# 1      Douglas Tucker  4478071379779230        16.054159
# 2      Travis Walters  6011812112971322        16.658734

# %%
df.set_index('Payer Name', drop=True, inplace=True)

# %%
df.head(3)
# Out:
#                     total_bill   tip     sex smoker  day    time  size  \
# Payer Name
# Christy Cunningham       16.99  1.01  Female     No  Sun  Dinner     2
# Douglas Tucker           10.34  1.66    Male     No  Sun  Dinner     3
# Travis Walters           21.01  3.50    Male     No  Sun  Dinner     3
#
#                     price_per_person         CC Number  Bonkörlük_faizi
# Payer Name
# Christy Cunningham              8.49  3560325168603410         5.944673
# Douglas Tucker                  3.45  4478071379779230        16.054159
# Travis Walters                  7.00  6011812112971322        16.658734

# %%
df.iloc[0] #integer location
# Out:
# total_bill                     16.99
# tip                             1.01
# sex                           Female
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               2
# price_per_person                8.49
# CC Number           3560325168603410
# Bonkörlük_faizi             5.944673
# Name: Christy Cunningham, dtype: object

# %%
df.iloc[1]
# Out:
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                3.45
# CC Number           4478071379779230
# Bonkörlük_faizi            16.054159
# Name: Douglas Tucker, dtype: object

# %%
df.loc['Douglas Tucker']
# Out:
# total_bill                     10.34
# tip                             1.66
# sex                             Male
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               3
# price_per_person                3.45
# CC Number           4478071379779230
# Bonkörlük_faizi            16.054159
# Name: Douglas Tucker, dtype: object

# %%
df.head(7)
# Out:
#                     total_bill   tip     sex smoker  day    time  size  \
# Payer Name
# Christy Cunningham       16.99  1.01  Female     No  Sun  Dinner     2
# Douglas Tucker           10.34  1.66    Male     No  Sun  Dinner     3
# Travis Walters           21.01  3.50    Male     No  Sun  Dinner     3
# Nathaniel Harris         23.68  3.31    Male     No  Sun  Dinner     2
# Tonya Carter             24.59  3.61  Female     No  Sun  Dinner     4
# Erik Smith               25.29  4.71    Male     No  Sun  Dinner     4
# Kristopher Johnson        8.77  2.00    Male     No  Sun  Dinner     2
#
#                     price_per_person         CC Number  Bonkörlük_faizi
# Payer Name
# Christy Cunningham              8.49  3560325168603410         5.944673
# Douglas Tucker                  3.45  4478071379779230        16.054159
# Travis Walters                  7.00  6011812112971322        16.658734
# Nathaniel Harris               11.84  4676137647685994        13.978041
# ...

# %%
df.iloc[2:6] #stop nöqtəsi daxil deyil
# Out:
#                   total_bill   tip     sex smoker  day    time  size  \
# Payer Name
# Travis Walters         21.01  3.50    Male     No  Sun  Dinner     3
# Nathaniel Harris       23.68  3.31    Male     No  Sun  Dinner     2
# Tonya Carter           24.59  3.61  Female     No  Sun  Dinner     4
# Erik Smith             25.29  4.71    Male     No  Sun  Dinner     4
#
#                   price_per_person         CC Number  Bonkörlük_faizi
# Payer Name
# Travis Walters                7.00  6011812112971322        16.658734
# Nathaniel Harris             11.84  4676137647685994        13.978041
# Tonya Carter                  6.15  4832732618637221        14.680765
# Erik Smith                    6.32   213140353657882        18.623962

# %%
df.loc['Travis Walters':'Erik Smith'] #stop nöqtəsi daxildir.
# Out:
#                   total_bill   tip     sex smoker  day    time  size  \
# Payer Name
# Travis Walters         21.01  3.50    Male     No  Sun  Dinner     3
# Nathaniel Harris       23.68  3.31    Male     No  Sun  Dinner     2
# Tonya Carter           24.59  3.61  Female     No  Sun  Dinner     4
# Erik Smith             25.29  4.71    Male     No  Sun  Dinner     4
#
#                   price_per_person         CC Number  Bonkörlük_faizi
# Payer Name
# Travis Walters                7.00  6011812112971322        16.658734
# Nathaniel Harris             11.84  4676137647685994        13.978041
# Tonya Carter                  6.15  4832732618637221        14.680765
# Erik Smith                    6.32   213140353657882        18.623962

# %%
df.iloc[4]
# Out:
# total_bill                     24.59
# tip                             3.61
# sex                           Female
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               4
# price_per_person                6.15
# CC Number           4832732618637221
# Bonkörlük_faizi            14.680765
# Name: Tonya Carter, dtype: object

# %%
df.loc['Tonya Carter']
# Out:
# total_bill                     24.59
# tip                             3.61
# sex                           Female
# smoker                            No
# day                              Sun
# time                          Dinner
# size                               4
# price_per_person                6.15
# CC Number           4832732618637221
# Bonkörlük_faizi            14.680765
# Name: Tonya Carter, dtype: object

# %%
df.head()
# Out:
#                     total_bill   tip     sex smoker  day    time  size  \
# Payer Name
# Christy Cunningham       16.99  1.01  Female     No  Sun  Dinner     2
# Douglas Tucker           10.34  1.66    Male     No  Sun  Dinner     3
# Travis Walters           21.01  3.50    Male     No  Sun  Dinner     3
# Nathaniel Harris         23.68  3.31    Male     No  Sun  Dinner     2
# Tonya Carter             24.59  3.61  Female     No  Sun  Dinner     4
#
#                     price_per_person         CC Number  Bonkörlük_faizi
# Payer Name
# Christy Cunningham              8.49  3560325168603410         5.944673
# Douglas Tucker                  3.45  4478071379779230        16.054159
# Travis Walters                  7.00  6011812112971322        16.658734
# Nathaniel Harris               11.84  4676137647685994        13.978041
# Tonya Carter                    6.15  4832732618637221        14.680765

# %%
df.drop('Travis Walters', axis=0, inplace=True)

# %%
df.head()
# Out:
#                     total_bill   tip     sex smoker  day    time  size  \
# Payer Name
# Christy Cunningham       16.99  1.01  Female     No  Sun  Dinner     2
# Douglas Tucker           10.34  1.66    Male     No  Sun  Dinner     3
# Nathaniel Harris         23.68  3.31    Male     No  Sun  Dinner     2
# Tonya Carter             24.59  3.61  Female     No  Sun  Dinner     4
# Erik Smith               25.29  4.71    Male     No  Sun  Dinner     4
#
#                     price_per_person         CC Number  Bonkörlük_faizi
# Payer Name
# Christy Cunningham              8.49  3560325168603410         5.944673
# Douglas Tucker                  3.45  4478071379779230        16.054159
# Nathaniel Harris               11.84  4676137647685994        13.978041
# Tonya Carter                    6.15  4832732618637221        14.680765
# Erik Smith                      6.32   213140353657882        18.623962

# %%
df.set_index('CC Number', drop= True,append= False, inplace=True)

# %%
df.head()
# Out:
#                   total_bill   tip     sex smoker  day    time  size  \
# CC Number
# 3560325168603410       16.99  1.01  Female     No  Sun  Dinner     2
# 4478071379779230       10.34  1.66    Male     No  Sun  Dinner     3
# 4676137647685994       23.68  3.31    Male     No  Sun  Dinner     2
# 4832732618637221       24.59  3.61  Female     No  Sun  Dinner     4
# 213140353657882        25.29  4.71    Male     No  Sun  Dinner     4
#
#                   price_per_person  Bonkörlük_faizi
# CC Number
# 3560325168603410              8.49         5.944673
# 4478071379779230              3.45        16.054159
# 4676137647685994             11.84        13.978041
# 4832732618637221              6.15        14.680765
# 213140353657882               6.32        18.623962

# %%
df.iloc[10:18]
# Out:
#                   total_bill   tip     sex smoker  day    time  size  \
# CC Number
# 4577817359320969       35.26  5.00  Female     No  Sun  Dinner     4
# 577040572932           15.42  1.57    Male     No  Sun  Dinner     2
# 6011163105616890       18.43  3.00    Male     No  Sun  Dinner     4
# 30016702287574         14.83  3.02  Female     No  Sun  Dinner     2
# 180073029785069        21.58  3.92    Male     No  Sun  Dinner     2
# 4240025044626033       10.33  1.67  Female     No  Sun  Dinner     3
# 6521340257218708       16.29  3.71    Male     No  Sun  Dinner     3
# 30422275171379         16.97  3.50  Female     No  Sun  Dinner     3
#
#                   price_per_person  Bonkörlük_faizi
# CC Number
# 4577817359320969              8.82        14.180374
# 577040572932                  7.71        10.181582
# 6011163105616890              4.61        16.277808
# 30016702287574                7.42        20.364127
# 180073029785069              10.79        18.164968
# ...

# %% [markdown]
# # DataFrame-də sorğular

# %%
df = pd.DataFrame({'Year': [1971,  1981, 2003, 2004], 'Pop': [328, 544, 200, 103], 'GDP': [20.1, 15.7, 18.3, 17.6]}, index=['USA', 'Canada', 'Mexico', 'Japan'])
df
# Out:
#         Year  Pop   GDP
# USA     1971  328  20.1
# Canada  1981  544  15.7
# Mexico  2003  200  18.3
# Japan   2004  103  17.6

# %%
df['Pop']
# Out:
# USA       328
# Canada    544
# Mexico    200
# Japan     103
# Name: Pop, dtype: int64

# %%
df['Pop'] > 150
# Out:
# USA        True
# Canada     True
# Mexico     True
# Japan     False
# Name: Pop, dtype: bool

# %%
df[df['Pop'] > 150]
# Out:
#         Year  Pop   GDP
# USA     1971  328  20.1
# Canada  1981  544  15.7
# Mexico  2003  200  18.3

# %%
df['Year']
# Out:
# USA       1971
# Canada    1981
# Mexico    2003
# Japan     2004
# Name: Year, dtype: int64

# %%
df[df['Year'] > 2000]
# Out:
#         Year  Pop   GDP
# Mexico  2003  200  18.3
# Japan   2004  103  17.6

# %%
df = pd.read_csv('/content/tips.csv')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df[df['total_bill'] > 40]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 95        40.17   4.73    Male    Yes   Fri  Dinner     4             10.04
# 102       44.30   2.50  Female    Yes   Sat  Dinner     3             14.77
# 142       41.19   5.00    Male     No  Thur   Lunch     5              8.24
# 156       48.17   5.00    Male     No   Sun  Dinner     6              8.03
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 182       45.35   3.50    Male    Yes   Sun  Dinner     3             15.12
# 184       40.55   3.00    Male    Yes   Sun  Dinner     2             20.27
# 197       43.11   5.00  Female    Yes  Thur   Lunch     4             10.78
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 59       Brian Ortiz  6596453823950595    Sat8139
# ...

# %%
df[df['sex'] == 'Male']
# Out:
#      total_bill   tip   sex smoker  day    time  size  price_per_person  \
# 1         10.34  1.66  Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50  Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31  Male     No  Sun  Dinner     2             11.84
# 5         25.29  4.71  Male     No  Sun  Dinner     4              6.32
# 6          8.77  2.00  Male     No  Sun  Dinner     2              4.38
# ..          ...   ...   ...    ...  ...     ...   ...               ...
# 236       12.60  1.00  Male    Yes  Sat  Dinner     2              6.30
# 237       32.83  1.17  Male    Yes  Sat  Dinner     2             16.42
# 239       29.03  5.92  Male     No  Sat  Dinner     3              9.68
# 241       22.67  2.00  Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75  Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df[df['sex'] == 'Female']
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# 11        35.26  5.00  Female     No   Sun  Dinner     4              8.82
# 14        14.83  3.02  Female     No   Sun  Dinner     2              7.42
# 16        10.33  1.67  Female     No   Sun  Dinner     3              3.44
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2              5.04
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2             11.06
# 238       35.83  4.67  Female     No   Sat  Dinner     3             11.94
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df[df['tip'] > 5]
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 44        30.40   5.60    Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00    Male     No   Sun  Dinner     4              8.10
# 52        34.81   5.20  Female     No   Sun  Dinner     4              8.70
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 85        34.83   5.17  Female     No  Thur   Lunch     4              8.71
# 88        24.71   5.85    Male     No  Thur   Lunch     2             12.36
# 116       29.93   5.07    Male     No   Sun  Dinner     4              7.48
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# 155       29.85   5.14  Female     No   Sun  Dinner     5              5.97
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# ...

# %%
df[(df['tip'] > 5) & (df['sex'] == 'Female')] # & simvolu And(ve) demekdir
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 52        34.81  5.20  Female     No   Sun  Dinner     4              8.70
# 85        34.83  5.17  Female     No  Thur   Lunch     4              8.71
# 155       29.85  5.14  Female     No   Sun  Dinner     5              5.97
# 214       28.17  6.50  Female    Yes   Sat  Dinner     3              9.39
#
#           Payer Name         CC Number Payment ID
# 52      Emily Daniel  4291280793094374    Sun6165
# 85       Shawna Cook  6011787464177340   Thur7972
# 155   Madison Wilson  4210875236164664    Sun9176
# 214  Marissa Jackson  4922302538691962    Sat3374

# %%
df[(df['sex'] == 'Male') & (df['tip'] > 5)]
# Out:
#      total_bill    tip   sex smoker   day    time  size  price_per_person  \
# 23        39.42   7.58  Male     No   Sat  Dinner     4              9.86
# 44        30.40   5.60  Male     No   Sun  Dinner     4              7.60
# 47        32.40   6.00  Male     No   Sun  Dinner     4              8.10
# 59        48.27   6.73  Male     No   Sat  Dinner     4             12.07
# 88        24.71   5.85  Male     No  Thur   Lunch     2             12.36
# 116       29.93   5.07  Male     No   Sun  Dinner     4              7.48
# 141       34.30   6.70  Male     No  Thur   Lunch     6              5.72
# 170       50.81  10.00  Male    Yes   Sat  Dinner     3             16.94
# 172        7.25   5.15  Male    Yes   Sun  Dinner     2              3.62
# 181       23.33   5.65  Male    Yes   Sun  Dinner     2             11.66
# 183       23.17   6.50  Male    Yes   Sun  Dinner     4              5.79
# 211       25.89   5.16  Male    Yes   Sat  Dinner     4              6.47
# ...

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
df[(df['day'] == 'Sun') & (df['total_bill'] > 30)]
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 11        35.26  5.00  Female     No  Sun  Dinner     4              8.82
# 44        30.40  5.60    Male     No  Sun  Dinner     4              7.60
# 47        32.40  6.00    Male     No  Sun  Dinner     4              8.10
# 52        34.81  5.20  Female     No  Sun  Dinner     4              8.70
# 112       38.07  4.00    Male     No  Sun  Dinner     3             12.69
# 156       48.17  5.00    Male     No  Sun  Dinner     6              8.03
# 167       31.71  4.50    Male     No  Sun  Dinner     4              7.93
# 173       31.85  3.18    Male    Yes  Sun  Dinner     2             15.92
# 175       32.90  3.11    Male    Yes  Sun  Dinner     2             16.45
# 179       34.63  3.55    Male    Yes  Sun  Dinner     2             17.32
# 180       34.65  3.68    Male    Yes  Sun  Dinner     4              8.66
# 182       45.35  3.50    Male    Yes  Sun  Dinner     3             15.12
# ...

# %%
df[(df['day'] == 'Sat') | (df['day'] == 'Sun')] # | simvolu Or(ve ya) demekdir
# Out:
#      total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No  Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...  ...     ...   ...               ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3             11.94
# 239       29.03  5.92    Male     No  Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No  Sat  Dinner     2              8.91
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df.sample(5)
# Out:
#     total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 78       22.76  3.00    Male     No  Thur   Lunch     2             11.38
# 43        9.68  1.32    Male     No   Sun  Dinner     2              4.84
# 16       10.33  1.67  Female     No   Sun  Dinner     3              3.44
# 73       25.28  5.00  Female    Yes   Sat  Dinner     2             12.64
# 99       12.46  1.50    Male     No   Fri  Dinner     2              6.23
#
#             Payer Name         CC Number Payment ID
# 78          Chris Hahn  3591887177014031   Thur2863
# 43  Christopher Spears  4387671121369212    Sun3279
# 16    Elizabeth Foster  4240025044626033    Sun9715
# 73        Julie Holmes  5418689346409571    Sat6065
# 99       Edward Carter   347435564751626    Fri5575

# %%
df[(df['day'] =='Sun') | (df['day']=='Sat') | (df['day'] == 'Thur')]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df[df['day'].isin(['Sun','Sat','Thur'])]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01  Female     No   Sun  Dinner     2              8.49
# 1         10.34  1.66    Male     No   Sun  Dinner     3              3.45
# 2         21.01  3.50    Male     No   Sun  Dinner     3              7.00
# 3         23.68  3.31    Male     No   Sun  Dinner     2             11.84
# 4         24.59  3.61  Female     No   Sun  Dinner     4              6.15
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df[df['day'] != 'Sun']
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 19        20.65  3.35    Male     No   Sat  Dinner     3              6.88
# 20        17.92  4.08    Male     No   Sat  Dinner     2              8.96
# 21        20.29  2.75  Female     No   Sat  Dinner     2             10.14
# 22        15.77  2.23  Female     No   Sat  Dinner     2              7.88
# 23        39.42  7.58    Male     No   Sat  Dinner     4              9.86
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# ...

# %%
df[~(df['day'] == 'Sun')]
# Out:
#      total_bill   tip     sex smoker   day    time  size  price_per_person  \
# 19        20.65  3.35    Male     No   Sat  Dinner     3              6.88
# 20        17.92  4.08    Male     No   Sat  Dinner     2              8.96
# 21        20.29  2.75  Female     No   Sat  Dinner     2             10.14
# 22        15.77  2.23  Female     No   Sat  Dinner     2              7.88
# 23        39.42  7.58    Male     No   Sat  Dinner     4              9.86
# ..          ...   ...     ...    ...   ...     ...   ...               ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3              9.68
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2             13.59
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2             11.34
# 242       17.82  1.75    Male     No   Sat  Dinner     2              8.91
# 243       18.78  3.00  Female     No  Thur  Dinner     2              9.39
#
#           Payer Name         CC Number Payment ID
# ...

# %%
#Done

# %%
# !pip install seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
plt.rcParams["figure.figsize"] = (10, 6)
plt.rcParams["xtick.labelsize"] = 14
plt.rcParams["ytick.labelsize"] = 14
plt.rcParams["axes.labelsize"] = 16

# %%
data = sns.load_dataset("penguins")
data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
data_male = data[data['sex'] == "Male"]["flipper_length_mm"]
data_male
# Out:
# 0      181.0
# 5      190.0
# 7      195.0
# 13     191.0
# 14     198.0
#        ...
# 333    230.0
# 335    230.0
# 337    222.0
# 341    222.0
# 343    213.0
# Name: flipper_length_mm, Length: 168, dtype: float64

# %%
data_female = data[data['sex'] == "Female"]["flipper_length_mm"]
data_female
# Out:
# 1      186.0
# 2      195.0
# 4      193.0
# 6      181.0
# 12     182.0
#        ...
# 332    213.0
# 334    217.0
# 338    214.0
# 340    215.0
# 342    212.0
# Name: flipper_length_mm, Length: 165, dtype: float64

# %%
sns.histplot(data=data_male, label="Male", alpha = 0.4)
sns.histplot(data= data_female, label="Female", alpha = 0.7)

plt.legend()
plt.show()

# %%
sns.histplot(data= data, x="flipper_length_mm",hue="sex",alpha = 0.8 )
plt.show()

# %%
sns.scatterplot(data = data, x ="bill_length_mm", y= "bill_depth_mm" , hue="species")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='bill_depth_mm'>

# %%
data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %% [markdown]
# # seaborn barplot

# %%
data
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
data_grouped = data.groupby(["species", "sex"])["body_mass_g"].mean().reset_index()
data_grouped
# Out:
#      species     sex  body_mass_g
# 0     Adelie  Female  3368.835616
# 1     Adelie    Male  4043.493151
# 2  Chinstrap  Female  3527.205882
# 3  Chinstrap    Male  3938.970588
# 4     Gentoo  Female  4679.741379
# 5     Gentoo    Male  5484.836066

# %%
sns.barplot(data=data_grouped, x = "species", y ="body_mass_g", hue="sex")
plt.show()

# %% [markdown]
# # Subplot

# %%
plt.subplots(2, 2, figsize=(12, 10))
# Out:
# (<Figure size 1200x1000 with 4 Axes>,
#  array([[<Axes: >, <Axes: >],
#         [<Axes: >, <Axes: >]], dtype=object))

# %%
dir(axes[0,0])
# Out:
# ['ArtistList',
#  '_AxesBase__clear',
#  '_PROPERTIES_EXCLUDED_FROM_SET',
#  '__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_add_text',
#  '_adjustable',
#  '_agg_filter',
#  '_alias_map',
#  '_alpha',
#  '_anchor',
#  '_animated',
#  '_aspect',
#  '_autotitlepos',
#  '_axes',
#  '_axes_locator',
#  '_axis_map',
#  '_axis_names',
#  '_axisbelow',
#  '_box_aspect',
#  '_callbacks',
#  '_check_no_units',
#  '_children',
#  '_clipon',
#  '_clippath',
#  '_cm_set',
#  '_colorbars',
#  '_convert_dx',
#  '_current_image',
#  '_different_canvas',
# ...

# %%
fig, axes = plt.subplots(2, 2, figsize=(12, 10))
sns.scatterplot(data= data, x = "bill_length_mm", y ="bill_depth_mm", hue= "species", ax = axes[0,0])
sns.boxplot(data= data, x = "species", y ="body_mass_g", ax = axes[0,1])
sns.histplot(data = data , x = "bill_length_mm", hue= "species" ,ax = axes[1,0])
axes[0,0].set_title("bill_length_mm vs bill_depth_mm")
axes[0,1].set_title("species & body_mass_g Boxplot")
plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.subplot(2, 2, 1)
sns.scatterplot(data= data, x = "bill_length_mm", y ="bill_depth_mm", hue= "species")
plt.subplot(2, 2, 2)
sns.boxplot(data= data, x = "species", y ="body_mass_g")
plt.subplot(2, 2, 3)
sns.histplot(data = data , x = "bill_depth_mm", hue= "sex", alpha= 0.8)
# Out:
# <Axes: xlabel='bill_depth_mm', ylabel='Count'>

# %%
data_grouped = data.groupby(["species"])["body_mass_g"].mean()
data_grouped
# Out:
# species
# Adelie       3700.662252
# Chinstrap    3733.088235
# Gentoo       5076.016260
# Name: body_mass_g, dtype: float64

# %%
data_grouped.index
# Out:
# Index(['Adelie', 'Chinstrap', 'Gentoo'], dtype='object', name='species')

# %%
data_grouped.values
# Out:
# array([3700.66225166, 3733.08823529, 5076.01626016])

# %%
sns.barplot(x = data_grouped.index, y = data_grouped.values )
plt.show()
